# %%
import pandas as pd
import numpy as np
import os as os

# %%
# !dir
# Out:
#  Volume in drive C is Windows
#  Volume Serial Number is 98FA-EFFA
#
#  Directory of C:\Users\gadam\anaconda
#
# 08-08-2024  14:20    <DIR>          .
# 03-08-2024  13:58    <DIR>          ..
# 08-08-2024  13:53    <DIR>          .ipynb_checkpoints
# 05-08-2024  12:05            16,467 arrays.ipynb
# 05-08-2024  00:01            25,002 control flow statements.ipynb
# 29-07-2024  13:07            30,764 data types and casting.ipynb
# 04-08-2024  12:46            46,523 dict.ipynb
# 05-08-2024  16:58            25,168 functions.ipynb
# 02-08-2024  12:51            54,745 list.ipynb
# 01-08-2024  13:12            28,393 operators and booleans .ipynb
# 29-07-2024  00:11            29,082 pyhtonintro.ipynb
# 02-08-2024  17:28            45,670 sets.ipynb
# 30-07-2024  00:11           117,996 strings.ipynb
# 02-08-2024  16:09            33,265 tuples.ipynb
# 05-08-2024  16:58            69,489 Untitled.ipynb
# 07-08-2024  17:04            83,282 Untitled1.ipynb
# ...

# %%
df=pd.read_csv(r"C:\Users\gadam\OneDrive\Pictures\Desktop\becsent\ml_v1.csv")
df
# Out:
#       lead_id  created_at  advance_emi  assigned_to      c_state      p_state  \
# 0        5357  05-06-2018            4         3394   Chandigarh   Chandigarh
# 1        8744  07-08-2018            3         3394        Delhi          NaN
# 2        8996  13-08-2018            6         3394        Delhi          NaN
# 3        9616  28-08-2018            6         3394  Maharashtra  Maharashtra
# 4        9690  30-08-2018            3         3394  Chattisgarh  West Bengal
# ...       ...         ...          ...          ...          ...          ...
# 1419    47804  31-07-2019            8         3394       Punjab       Punjab
# 1420    47811  31-07-2019            5         3394        Delhi        Delhi
# 1421    48006  31-07-2019            6         3394       Kerala          NaN
# 1422    48047  31-07-2019            2         3394  Uttarakhand          NaN
# 1423    48096  31-07-2019            1         3394    Jharkhand          NaN
#
# ...

# %%
df.head()
# Out:
#    lead_id  created_at  advance_emi  assigned_to      c_state      p_state  \
# 0     5357  05-06-2018            4         3394   Chandigarh   Chandigarh
# 1     8744  07-08-2018            3         3394        Delhi          NaN
# 2     8996  13-08-2018            6         3394        Delhi          NaN
# 3     9616  28-08-2018            6         3394  Maharashtra  Maharashtra
# 4     9690  30-08-2018            3         3394  Chattisgarh  West Bengal
#
#   hospitalObject.type  age  age_group borrower.gender  ...  speciality_id  \
# 0               super   46          4            male  ...           58.0
# 1               multi   33          2            male  ...            1.0
# 2               super   34          2            male  ...           58.0
# 3               super   36          3            male  ...            1.0
# 4          single_ivf   38          3            male  ...            1.0
#
#                  state submitted_by  subvention_percentage  \
# ...

# %%
df.tail(5)
# Out:
#       lead_id  created_at  advance_emi  assigned_to      c_state p_state  \
# 1419    47804  31-07-2019            8         3394       Punjab  Punjab
# 1420    47811  31-07-2019            5         3394        Delhi   Delhi
# 1421    48006  31-07-2019            6         3394       Kerala     NaN
# 1422    48047  31-07-2019            2         3394  Uttarakhand     NaN
# 1423    48096  31-07-2019            1         3394    Jharkhand     NaN
#
#      hospitalObject.type  age  age_group borrower.gender  ...  speciality_id  \
# 1419          single_ivf   28          1            male  ...            1.0
# 1420          single_ivf   36          3            male  ...            1.0
# 1421               multi   32          2            male  ...           71.0
# 1422     single_cosmetic   23          0            male  ...           71.0
# 1423     single_cosmetic   35          3            male  ...           71.0
#
# ...
